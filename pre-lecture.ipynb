# %% [markdown]
# <a href="https://colab.research.google.com/github/ElieRu/pre-lecture-practice/blob/main/pre-lecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# create and manage my variables
name = "john"
age = '30'

# Data Types
print(type(name))

# Type Conversion
newType = int(age)
# print(type(newType))

# Collections (lists, tules, dictionary)
users = ['john', 'jane', 'back'] # list
users.append('jimmy')
users.remove('john')
newUsers = users[-1]

workers = ('obama', 'smith') # tuple
# its sisimer to a list, but the order cannot chanage

books = {
    'book1': 'the new day',
    'book2': 'the sun shine',
} # dictionary
# print(books)

# if statement
if (type(age) != 'int'):
  int(age)
else:
  print("the age is an int")

# for statement
for i, user in enumerate(users):
  print(i, user)

# function
def my_age(age):
  print('You are ',age,'years old')
my_age(4)

# Module
# Library (numpy, math)
# class
class User:
  def __init__(self, name: str):
    self.name = name
  def get_user(self):
    return self.name

user = User("john doe")
print(user.get_user())
# Out:
# <class 'str'>
# 0 jane
# 1 back
# 2 jimmy
# You are  4 years old
# john doe
