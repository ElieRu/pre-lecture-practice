# %% [markdown]
# <a href="https://colab.research.google.com/github/ElieRu/pre-lecture/blob/main/pre-lecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i = 90
print(i)
# Out:
# 90
